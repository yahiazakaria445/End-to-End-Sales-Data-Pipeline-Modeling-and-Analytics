# %%
pip install great_expectations
# Out:
# Requirement already satisfied: great_expectations in c:\users\yahia zakaria\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: cryptography>=3.2 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (43.0.0)
# Requirement already satisfied: jinja2>=3 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (3.1.4)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (4.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (2.0.4)
# Requirement already satisfied: packaging in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (24.1)
# Requirement already satisfied: posthog<4,>3 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (3.25.0)
# Requirement already satisfied: pydantic>=1.10.7 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (2.8.2)
# Requirement already satisfied: pyparsing>=2.4 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (2.9.0.post0)
# Requirement already satisfied: requests>=2.20 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (2.32.3)
# Requirement already satisfied: ruamel.yaml>=0.16 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (0.18.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (1.13.1)
# Requirement already satisfied: tqdm>=4.59.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (4.11.0)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: pandas<2.2,>=1.3.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from great_expectations) (2.1.4)
# Requirement already satisfied: entrypoints in c:\users\yahia zakaria\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in c:\users\yahia zakaria\anaconda3\lib\site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from cryptography>=3.2->great_expectations) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from jinja2>=3->great_expectations) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.10.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from pandas<2.2,>=1.3.0->great_expectations) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from posthog<4,>3->great_expectations) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from posthog<4,>3->great_expectations) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from posthog<4,>3->great_expectations) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from posthog<4,>3->great_expectations) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from pydantic>=1.10.7->great_expectations) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from pydantic>=1.10.7->great_expectations) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from requests>=2.20->great_expectations) (2025.1.31)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\yahia zakaria\anaconda3\lib\site-packages (from ruamel.yaml>=0.16->great_expectations) (0.2.8)
# Requirement already satisfied: colorama in c:\users\yahia zakaria\anaconda3\lib\site-packages (from tqdm>=4.59.0->great_expectations) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\yahia zakaria\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import great_expectations as gx
context = gx.get_context()
assert type(context).__name__ == "EphemeralDataContext"

# %%
import pandas as pd
pizza_data_df = pd.read_csv("pizza_sales.csv")


data_source = context.data_sources.add_pandas(name="pizza_sales_source")


data_asset = data_source.add_dataframe_asset(name="pizza_sales_asset")

# %%
batch_definition_name = "pizza_sales_batch"

batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)
assert batch_definition.name == batch_definition_name

# %%
batch_parameters = {"dataframe": pizza_data_df}


batch = batch_definition.get_batch(batch_parameters=batch_parameters)

# %%
expectation_suite_name = "pizza_data_suite"
suite = gx.ExpectationSuite(name=expectation_suite_name)


suite.add_expectation(gx.expectations.ExpectColumnValuesToNotBeNull(column="pizza_id"))
suite.add_expectation(gx.expectations.ExpectColumnValuesToNotBeNull(column="order_id"))
suite.add_expectation(gx.expectations.ExpectColumnValuesToNotBeNull(column="pizza_name_id"))
suite.add_expectation(gx.expectations.ExpectColumnValuesToNotBeNull(column="pizza_name"))
suite.add_expectation(gx.expectations.ExpectColumnValuesToNotBeNull(column="pizza_size"))
suite.add_expectation(gx.expectations.ExpectColumnValuesToNotBeNull(column="order_date"))
suite.add_expectation(gx.expectations.ExpectColumnValuesToNotBeNull(column="order_time"))


suite.add_expectation(gx.expectations.ExpectColumnValuesToBeBetween(column="quantity", min_value=1))
suite.add_expectation(gx.expectations.ExpectColumnValuesToBeBetween(column="unit_price", min_value=0))
suite.add_expectation(gx.expectations.ExpectColumnValuesToBeBetween(column="total_price", min_value=0))


suite.add_expectation(gx.expectations.ExpectColumnValuesToBeInSet(
    column="pizza_size",
    value_set=["S", "M", "L", "XL", "XXL"]
))


suite.add_expectation(gx.expectations.ExpectColumnValuesToBeInSet(
    column="pizza_category",
    value_set=["Classic", "Veggie", "Supreme", "Chicken"]
))


suite.add_expectation(gx.expectations.ExpectColumnValuesToMatchStrftimeFormat(
    column="order_date",
    strftime_format="%m/%d/%Y"
))


suite.add_expectation(gx.expectations.ExpectColumnValuesToMatchStrftimeFormat(
    column="order_time",
    strftime_format="%H:%M:%S"
))


suite.add_expectation(gx.expectations.ExpectColumnValuesToBeUnique(column="pizza_id"))


context.suites.add(suite)
# Out:
# {
#   "name": "pizza_data_suite",
#   "id": "0f9026e5-5d2a-4f80-9485-8765cb65ea90",
#   "expectations": [
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "pizza_id"
#       },
#       "meta": {},
#       "id": "02cf3163-7d66-4229-af16-6b0b0f03c802"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "order_id"
#       },
#       "meta": {},
#       "id": "f70d0320-f792-419a-a408-00b663abc357"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "pizza_name_id"
#       },
#       "meta": {},
#       "id": "d49cee66-4dfb-485d-b0c9-800938610bed"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "pizza_name"
#       },
#       "meta": {},
#       "id": "9e74f71b-1f95-4cb3-bae4-82a3b8d4f15b"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "pizza_size"
#       },
#       "meta": {},
#       "id": "bb280026-426c-49ef-bdeb-11735abe7f7d"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "order_date"
#       },
#       "meta": {},
#       "id": "300703a7-aee4-4fb3-891f-84b23ba6531d"
#     },
#     {
#       "type": "expect_column_values_to_not_be_null",
#       "kwargs": {
#         "column": "order_time"
#       },
#       "meta": {},
#       "id": "ea35d6c6-103a-42f9-8661-2edacea4f3cc"
#     },
#     {
#       "type": "expect_column_values_to_be_between",
#       "kwargs": {
#         "column": "quantity",
#         "min_value": 1.0
#       },
#       "meta": {},
#       "id": "d7c2faf1-cb1b-4ee9-81d3-239c9b834d26"
#     },
#     {
#       "type": "expect_column_values_to_be_between",
#       "kwargs": {
#         "column": "unit_price",
#         "min_value": 0.0
#       },
#       "meta": {},
#       "id": "124cd292-63cb-496a-8889-421d6d5ba77f"
#     },
#     {
#       "type": "expect_column_values_to_be_between",
#       "kwargs": {
#         "column": "total_price",
#         "min_value": 0.0
#       },
#       "meta": {},
#       "id": "66277447-ca4f-411a-948a-86bf85da2bc7"
#     },
#     {
#       "type": "expect_column_values_to_be_in_set",
#       "kwargs": {
#         "column": "pizza_size",
#         "value_set": [
#           "S",
#           "M",
#           "L",
#           "XL",
#           "XXL"
#         ]
#       },
#       "meta": {},
#       "id": "fbd7046e-5276-4676-815c-510d8eff57d5"
#     },
#     {
#       "type": "expect_column_values_to_be_in_set",
#       "kwargs": {
#         "column": "pizza_category",
#         "value_set": [
#           "Classic",
#           "Veggie",
#           "Supreme",
#           "Chicken"
#         ]
#       },
#       "meta": {},
#       "id": "20b3c36c-60fe-44b6-ab2d-2609c92b714f"
#     },
#     {
#       "type": "expect_column_values_to_match_strftime_format",
#       "kwargs": {
#         "column": "order_date",
#         "strftime_format": "%m/%d/%Y"
#       },
#       "meta": {},
#       "id": "943e4984-6a6e-43c8-8c73-7b7b91a3f66b"
#     },
#     {
#       "type": "expect_column_values_to_match_strftime_format",
#       "kwargs": {
#         "column": "order_time",
#         "strftime_format": "%H:%M:%S"
#       },
#       "meta": {},
#       "id": "78e24447-79f3-4407-acd0-39031db5c403"
#     },
#     {
#       "type": "expect_column_values_to_be_unique",
#       "kwargs": {
#         "column": "pizza_id"
#       },
#       "meta": {},
#       "id": "1a2c89ee-ffe2-4c06-aaac-dd69fa1688b2"
#     }
#   ],
#   "meta": {
#     "great_expectations_version": "1.4.2"
#   },
#   "notes": null
# }

# %%
validation_results = batch.validate(suite)
print(validation_results)
# Out:
# Calculating Metrics:   0%|          | 0/91 [00:00<?, ?it/s]
# {
#   "success": false,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "pizza_id"
#         },
#         "meta": {},
#         "id": "02cf3163-7d66-4229-af16-6b0b0f03c802"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_unique",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "pizza_id"
#         },
#         "meta": {},
#         "id": "1a2c89ee-ffe2-4c06-aaac-dd69fa1688b2"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "order_id"
#         },
#         "meta": {},
#         "id": "f70d0320-f792-419a-a408-00b663abc357"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "pizza_name_id"
#         },
#         "meta": {},
#         "id": "d49cee66-4dfb-485d-b0c9-800938610bed"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "pizza_name"
#         },
#         "meta": {},
#         "id": "9e74f71b-1f95-4cb3-bae4-82a3b8d4f15b"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "pizza_size"
#         },
#         "meta": {},
#         "id": "bb280026-426c-49ef-bdeb-11735abe7f7d"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_in_set",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "pizza_size",
#           "value_set": [
#             "S",
#             "M",
#             "L",
#             "XL",
#             "XXL"
#           ]
#         },
#         "meta": {},
#         "id": "fbd7046e-5276-4676-815c-510d8eff57d5"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "order_date"
#         },
#         "meta": {},
#         "id": "300703a7-aee4-4fb3-891f-84b23ba6531d"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_match_strftime_format",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "order_date",
#           "strftime_format": "%m/%d/%Y"
#         },
#         "meta": {},
#         "id": "943e4984-6a6e-43c8-8c73-7b7b91a3f66b"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 29033,
#         "unexpected_percent": 59.714109419991765,
#         "partial_unexpected_list": [
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015",
#           "13-01-2015"
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 59.714109419991765,
#         "unexpected_percent_nonmissing": 59.714109419991765,
#         "partial_unexpected_counts": [
#           {
#             "value": "13-01-2015",
#             "count": 20
#           }
#         ],
#         "partial_unexpected_index_list": [
#           1650,
#           1651,
#           1652,
#           1653,
#           1654,
#           1655,
#           1656,
#           1657,
#           1658,
#           1659,
#           1660,
#           1661,
#           1662,
#           1663,
#           1664,
#           1665,
#           1666,
#           1667,
#           1668,
#           1669
#         ]
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "order_time"
#         },
#         "meta": {},
#         "id": "ea35d6c6-103a-42f9-8661-2edacea4f3cc"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_match_strftime_format",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "order_time",
#           "strftime_format": "%H:%M:%S"
#         },
#         "meta": {},
#         "id": "78e24447-79f3-4407-acd0-39031db5c403"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "quantity",
#           "min_value": 1.0
#         },
#         "meta": {},
#         "id": "d7c2faf1-cb1b-4ee9-81d3-239c9b834d26"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "unit_price",
#           "min_value": 0.0
#         },
#         "meta": {},
#         "id": "124cd292-63cb-496a-8889-421d6d5ba77f"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "total_price",
#           "min_value": 0.0
#         },
#         "meta": {},
#         "id": "66277447-ca4f-411a-948a-86bf85da2bc7"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_in_set",
#         "kwargs": {
#           "batch_id": "pizza_sales_source-pizza_sales_asset",
#           "column": "pizza_category",
#           "value_set": [
#             "Classic",
#             "Veggie",
#             "Supreme",
#             "Chicken"
#           ]
#         },
#         "meta": {},
#         "id": "20b3c36c-60fe-44b6-ab2d-2609c92b714f"
#       },
#       "result": {
#         "element_count": 48620,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "pizza_data_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 15,
#     "successful_expectations": 14,
#     "unsuccessful_expectations": 1,
#     "success_percent": 93.33333333333333
#   },
#   "meta": {
#     "great_expectations_version": "1.4.2",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250606T112141.717275Z",
#       "pandas_data_fingerprint": "6e2cb7679ea586c050629ea79617327a"
#     },
#     "active_batch_definition": {
#       "datasource_name": "pizza_sales_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "pizza_sales_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     }
#   },
#   "id": null
# }

# %%
context.build_data_docs()
# Out:
# {'local_site': 'file://C:\\Users\\YAHIAZ~1\\AppData\\Local\\Temp\\tmp9dgp0md9\\index.html'}
